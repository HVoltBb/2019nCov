# %% [markdown]
# # Code example
# In this notebook, I will go through sections of the code to do the analysis as in [here](https://doi.org/10.1101/2020.02.15.20023440).
# First, we need to import required libraries.

# %%
from scipy.integrate import odeint
import numpy as np
import theano
from theano import *
import matplotlib.pyplot as plt
import pymc3 as pm
import csv

# %% [markdown]
# Next, we need a class object for the SEIR model and the SEAIR model:

# %%
class nCov2019v1(object):
    def __init__(self, times, cw, wc, y0=None):
            self._y0 = np.array([14e6, 0,0,0,0,0], dtype=np.float64)
            self._times = times
            self._cw = cw
            self._wc = wc

    def _simulate(self, parameters, times):
        R0, = [float(x) for x in parameters]

        # Time constants
        De = 3
        Di = 8.4 - De
        
        def rhs(y, t, p):
            
            # Connectivity numbers
            Liw = 3546.
            Lwi = 3633.
            
            if t<31:
                Lwc = 502013
                Lcw = 487310
            elif t<= 32:
              Lwc = self._wc[1]
              Lcw = self._cw[1]
            elif t<= 33:
              Lwc = self._wc[2]
              Lcw = self._cw[2]
            elif t<= 34:
              Lwc = self._wc[3]
              Lcw = self._cw[3]
            elif t<= 35:
              Lwc = self._wc[4]
              Lcw = self._cw[4]
            elif t<= 36:
              Lwc = self._wc[5]
              Lcw = self._cw[5]
            elif t<= 37:
              Lwc = self._wc[6]
              Lcw = self._cw[6]
            elif t<= 38:
              Lwc = self._wc[7]
              Lcw = self._cw[7]
            elif t<= 39:
              Lwc = self._wc[8]
              Lcw = self._cw[8]
            elif t<= 40:
              Lwc = self._wc[9]
              Lcw = self._cw[9]
            elif t<= 41:
              Lwc = self._wc[10]
              Lcw = self._cw[10]
            elif t<= 42:
              Lwc = self._wc[11]
              Lcw = self._cw[11]
            elif t<= 43:
              Lwc = self._wc[12]
              Lcw = self._cw[12]
            elif t<= 44:
              Lwc = self._wc[13]
              Lcw = self._cw[13]
            elif t<= 45:
              Lwc = self._wc[14]
              Lcw = self._cw[14]
            elif t<= 46:
              Lwc = self._wc[15]
              Lcw = self._cw[15]
            elif t<= 47:
              Lwc = self._wc[16]
              Lcw = self._cw[16]
            elif t<= 48:
              Lwc = self._wc[17]
              Lcw = self._cw[17]
            elif t<= 49:
              Lwc = self._wc[18]
              Lcw = self._cw[18]
            elif t<= 50:
              Lwc = self._wc[19]
              Lcw = self._cw[19]
            elif t<= 51:
              Lwc = self._wc[20]
              Lcw = self._cw[20]
            elif t<= 52:
              Lwc = self._wc[21]
              Lcw = self._cw[21]
            elif t<= 53:
              Lwc = self._wc[22]
              Lcw = self._cw[22]
            elif t<= 54:
              Lwc = self._wc[23]
              Lcw = self._cw[23]
            elif t<= 55:
              Lwc = self._wc[24]
              Lcw = self._cw[24]
            elif t<= 56:
              Lwc = self._wc[25]
              Lcw = self._cw[25]
            elif t<= 57:
              Lwc = self._wc[26]
              Lcw = self._cw[26]
            elif t<= 58:
              Lwc = self._wc[27]
              Lcw = self._cw[27]
            else:
                Lcw = 0.
                Lwc = 0.
                
            if(t>=54):
                Lwi = Lwi*(1-1/(1+np.exp(54.5-t)))
                Liw = Liw*(1-1/(1+np.exp(54.5-t)))
                
            # Zoonic source
            if t<31:
                z = 43*2.
            else:
                z = 0.
            
            S, E, I, R, XX, YY = y
            N = S + E + I + R
            dS_dt = -S/N*(R0/Di*I + z) + Liw + Lcw - (Lwi/N + Lwc/N)*S
            dE_dt = S/N*(R0/Di*I + z) - E/De - (Lwi/N + Lwc/N)*E
            dI_dt = E/De - I/Di - (Lwi/N + Lwc/N)*I
            dR_dt = I/Di
            dexport = Lwi*(E+I)/N
            dcumI = E/De
            return dS_dt, dE_dt, dI_dt, dR_dt, dexport, dcumI
        values = odeint(rhs, self._y0, times, (parameters,),rtol=1e-3,atol=1e-3)
        return values

    def simulate(self, x):
        return self._simulate(x, self._times)

# %%
class nCov2019v2(object):
    def __init__(self, times, cw, wc, y0=None):
            self._y0 = np.array([14e6, 0,0,0,0,0,0], dtype=np.float64)
            self._times = times
            self._cw = cw
            self._wc = wc

    def _simulate(self, parameters, times):
        R0,mul = [float(x) for x in parameters]

        # Time constants
        De = 3*mul
        Dei = 3-De
        Di = 5.4
        
        def rhs(y, t, p):
            
            # Connectivity numbers
            Liw = 3546.
            Lwi = 3633.
            
            if t<31:
                Lwc = 502013
                Lcw = 487310
            elif t<= 32:
              Lwc = self._wc[1]
              Lcw = self._cw[1]
            elif t<= 33:
              Lwc = self._wc[2]
              Lcw = self._cw[2]
            elif t<= 34:
              Lwc = self._wc[3]
              Lcw = self._cw[3]
            elif t<= 35:
              Lwc = self._wc[4]
              Lcw = self._cw[4]
            elif t<= 36:
              Lwc = self._wc[5]
              Lcw = self._cw[5]
            elif t<= 37:
              Lwc = self._wc[6]
              Lcw = self._cw[6]
            elif t<= 38:
              Lwc = self._wc[7]
              Lcw = self._cw[7]
            elif t<= 39:
              Lwc = self._wc[8]
              Lcw = self._cw[8]
            elif t<= 40:
              Lwc = self._wc[9]
              Lcw = self._cw[9]
            elif t<= 41:
              Lwc = self._wc[10]
              Lcw = self._cw[10]
            elif t<= 42:
              Lwc = self._wc[11]
              Lcw = self._cw[11]
            elif t<= 43:
              Lwc = self._wc[12]
              Lcw = self._cw[12]
            elif t<= 44:
              Lwc = self._wc[13]
              Lcw = self._cw[13]
            elif t<= 45:
              Lwc = self._wc[14]
              Lcw = self._cw[14]
            elif t<= 46:
              Lwc = self._wc[15]
              Lcw = self._cw[15]
            elif t<= 47:
              Lwc = self._wc[16]
              Lcw = self._cw[16]
            elif t<= 48:
              Lwc = self._wc[17]
              Lcw = self._cw[17]
            elif t<= 49:
              Lwc = self._wc[18]
              Lcw = self._cw[18]
            elif t<= 50:
              Lwc = self._wc[19]
              Lcw = self._cw[19]
            elif t<= 51:
              Lwc = self._wc[20]
              Lcw = self._cw[20]
            elif t<= 52:
              Lwc = self._wc[21]
              Lcw = self._cw[21]
            elif t<= 53:
              Lwc = self._wc[22]
              Lcw = self._cw[22]
            elif t<= 54:
              Lwc = self._wc[23]
              Lcw = self._cw[23]
            elif t<= 55:
              Lwc = self._wc[24]
              Lcw = self._cw[24]
            elif t<= 56:
              Lwc = self._wc[25]
              Lcw = self._cw[25]
            elif t<= 57:
              Lwc = self._wc[26]
              Lcw = self._cw[26]
            elif t<= 58:
              Lwc = self._wc[27]
              Lcw = self._cw[27]
            else:
                Lcw = 0.
                Lwc = 0.
                
            if(t>=54):
                Lwi = Lwi*(1-1/(1+np.exp(54.5-t)))
                Liw = Liw*(1-1/(1+np.exp(54.5-t)))
                
            # Zoonic source
            if t<31:
                z = 43*2.
            else:
                z = 0.
            
            S, E, EI, I, R, XX, YY = y
            N = S + E + I + R + EI
            dS_dt = -S/N*(R0/Di*(EI+I) + z) + Liw + Lcw - (Lwi/N + Lwc/N)*S
            dE_dt = S/N*(R0/Di*(EI+I) + z) - E/De - (Lwi/N + Lwc/N)*E
            dEI_dt= E/De - EI/Dei - (Lwi/N + Lwc/N)*EI
            dI_dt = EI/Dei - I/Di - (Lwi/N + Lwc/N)*I
            dR_dt = I/Di
            dexport = Lwi*(E+EI+I)/N
            dcumI = E/De
            return dS_dt, dE_dt, dEI_dt, dI_dt, dR_dt, dexport, dcumI
        values = odeint(rhs, self._y0, times, (parameters,),rtol=1e-3,atol=1e-3)
        return values

    def simulate(self, x):
        return self._simulate(x, self._times)

# %% [markdown]
# ## Preprocess the data
# All three input data are loaded into python and converted to numpy objects.
# 1, the internationally exported cases:

# %%
data = []
with open('CaseExp.csv') as file:
    data = list(csv.reader(file))

# %%
from datetime import date, datetime

dec1 = datetime(2019, 12, 1) # Day 0 in this study

xd = []
xdRel = []
for x in range(1, len(data)):
    if data[x][3] != '':
       xd.append(datetime.strptime(data[x][3], '%m/%d/%y'))
    elif data[x][1] != '':
        xd.append(datetime.strptime(data[x][1], '%m/%d/%y'))
    else:
        xd.append(datetime.strptime(data[x][2], '%m/%d/%y'))
    xdRel.append((xd[x-1] - dec1).days)

# %%
from collections import Counter

tb = np.array(sorted(Counter(xdRel).items()))

# %% [markdown]
# 2, the evacuees dataset:

# %%
data = []
with open("Evacuee.csv") as file:
    data = list(csv.reader(file))

ev = []
evRel = []
for x in range(1, len(data)):
    if data[x][3] != '':
        time = [datetime.strptime(data[x][5] + '/20', '%m/%d/%y')]
        evRel.append([(time[0] - dec1).days, float(data[x][2]), float(data[x][3])])

evRel = np.array(evRel).astype(int)

# %% [markdown]
# 3, the real time heat index from Baidu:

# %%
with open('RealtimeTraffic.csv') as file:
    data = list(csv.reader(file))

fctr = 138412.01 # estimated scaling factor based on calibrated Tencent data from Wu(2020)
flow = np.array(data)

cw = flow[1:50,2]
cw[cw==''] = 0
cw = cw.astype(float) * fctr

wc = flow[51:97,2]
wc[wc==''] = 0
wc = wc.astype(float) * fctr

# %% [markdown]
# ## Fit the models
# First, we need two theano operators for the two models.

# %%
import theano.tensor as tt
from theano.compile.ops import as_op

modelv1 = nCov2019v1(np.linspace(0, 65, 66), cw, wc)
modelv2 = nCov2019v2(np.linspace(0, 65, 66), cw, wc)

@as_op(itypes=[tt.dscalar, tt.dscalar], otypes=[tt.dmatrix])
def th_forward_modelv2(param1, param2):

    param = [param1, param2]
    th_states = modelv2.simulate(param)

    return th_states

@as_op(itypes=[tt.dscalar], otypes=[tt.dmatrix])
def th_forward_modelv1(param1):
    
    param = [param1]
    th_states = modelv1.simulate(param)
    
    return th_states

# %% [markdown]
# Next, draw 5000 samples from the posterier of the SEAIR model:

# %%
draws = 5000

with pm.Model() as ncov_model:
    
    # Priors
    r0 = pm.Uniform('r0', lower=1, upper=10)
    mul= pm.Uniform('mul', lower=1e-5, upper=1-1e-5)
    
    out = th_forward_modelv2(r0, mul)
    lam = out[tuple(tb[:,0]), 5] - out[tuple(tb[:,0]-1), 5]
    # data:observed=tb[:,1]
    JoWu = pm.Poisson('xpted', mu=lam, observed=tb[:,1])
    # data:evRel[:,2]
    Evac = pm.Binomial('exv', n=evRel[:,1], 
                       p=(out[tuple(evRel[:,0]), 1] + out[tuple(evRel[:,0]), 2])
                       /(out[tuple(evRel[:,0]), 0] + out[tuple(evRel[:,0]), 1] + out[tuple(evRel[:,0]), 4] 
                          + out[tuple(evRel[:,0]), 2]), observed = evRel[:,2])

    trace = pm.sample_smc(draws, parallel=True, cores = 8)
# Out:
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# Stage:   0 Beta: 0.004 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.006 Steps:  25 Acce: 0.819
# Stage:   2 Beta: 0.008 Steps:   2 Acce: 0.522
# Stage:   3 Beta: 0.008 Steps:   6 Acce: 0.432
# Stage:   4 Beta: 0.021 Steps:   8 Acce: 0.159
# Stage:   5 Beta: 0.141 Steps:  25 Acce: 0.025
# Stage:   6 Beta: 0.889 Steps:  25 Acce: 0.020
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.019

# %% [markdown]
# Next, draw 5000 samples from the posterier of the SEIR model:

# %%
draws = 5000

with pm.Model() as ncov_model0:
    
    # Priors
    r0 = pm.Uniform('r0', lower=1, upper=10)
    
    out = th_forward_modelv1(r0)
    lam = out[tuple(tb[:,0]), 4] - out[tuple(tb[:,0]-1), 4]
    
    JoWu = pm.Poisson('xpted', mu=lam, observed=tb[:,1])
    
    Evac = pm.Binomial('exv', n=evRel[:,1], 
                       p=(out[tuple(evRel[:,0]), 1])/
                       (out[tuple(evRel[:,0]), 0] + out[tuple(evRel[:,0]), 1] + out[tuple(evRel[:,0]), 3]),
                       observed = evRel[:,2])
    
    trace = pm.sample_smc(draws, parallel=True, cores = 8)
# Out:
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.689
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.535
# Stage:   3 Beta: 0.018 Steps:   6 Acce: 0.514
# Stage:   4 Beta: 0.136 Steps:   6 Acce: 0.321
# Stage:   5 Beta: 0.849 Steps:  11 Acce: 0.297
# Stage:   6 Beta: 1.000 Steps:  13 Acce: 0.267

# %% [markdown]
# You can plot the posterier estimates, and also save them as csv files.

# %%
pm.plot_posterior(trace, kind='hist', bins=15, color='seagreen');

# %%
np.savetxt('postr0.csv', trace.get_values('r0'), delimiter=',')
np.savetxt('postmul.csv', trace.get_values('mul'), delimiter=',')

# %% [markdown]
# ## Fit the bootstrap sample
# A bootstrap sample is generated in R and saved in SimP.csv (the internationally exported cases) and SimB.csv (the exacuee data). Here P stands for Poisson, and B for Binomial.

# %%
## Simulation
with open('simB.csv') as file:
    data = list(csv.reader(file))
Bdata = np.array(data)
Bdata = Bdata[1:(Bdata.shape[0]+1),1:16].astype(float)

with open('simP.csv') as file:
    data = list(csv.reader(file))
Pdata = np.array(data)
Pdata = Pdata[1:(Pdata.shape[0]+1), 1:19].astype(float)

# %% [markdown]
# The following code will go through each of the bootstrap sample and fit the SEIR model for each of them. Be aware that it takes several hours to finish on an i7 Intel machine. So plan ahead before runing the following code. It also helps to run a smaller batch on your machine to check for potential errors.

# %%
#sim bs
## simulation
num = min(Bdata.shape[0], 100)
draws = 5000
postSimR0b = np.zeros((num, draws))

for i in range(num):
    with pm.Model() as ncov_model:
    
        # Priors
        r0 = pm.Uniform('r0', lower=1, upper=10)

        out = th_forward_modelv1(r0)
        lam = out[tuple(tb[:,0]), 4] - out[tuple(tb[:,0]-1), 4]
        # data:observed=tb[:,1]
        JoWu = pm.Poisson('xpted', mu=lam, observed=Pdata[i,])
        # data:evRel[:,2]
        Evac = pm.Binomial('exv', n=evRel[:,1], 
                       p=(out[tuple(evRel[:,0]), 1])/
                       (out[tuple(evRel[:,0]), 0] + out[tuple(evRel[:,0]), 1] + out[tuple(evRel[:,0]), 3]),
                       observed = Bdata[i,])

        trace = pm.sample_smc(draws, parallel=True, cores = 8)
        postSimR0b[i,:] = trace.get_values('r0')
# Out:
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.644
# Stage:   2 Beta: 0.011 Steps:   4 Acce: 0.590
# Stage:   3 Beta: 0.031 Steps:   5 Acce: 0.510
# Stage:   4 Beta: 0.177 Steps:   6 Acce: 0.412
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.255
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.702
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.543
# Stage:   3 Beta: 0.023 Steps:   5 Acce: 0.566
# Stage:   4 Beta: 0.127 Steps:   5 Acce: 0.224
# Stage:   5 Beta: 0.654 Steps:  18 Acce: 0.248
# Stage:   6 Beta: 1.000 Steps:  16 Acce: 0.254
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.681
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.555
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.550
# Stage:   4 Beta: 0.147 Steps:   5 Acce: 0.440
# Stage:   5 Beta: 1.000 Steps:   7 Acce: 0.233
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.687
# Stage:   2 Beta: 0.015 Steps:   3 Acce: 0.463
# Stage:   3 Beta: 0.015 Steps:   7 Acce: 0.504
# Stage:   4 Beta: 0.294 Steps:   6 Acce: 0.502
# Stage:   5 Beta: 1.000 Steps:   6 Acce: 0.225
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.661
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.635
# Stage:   3 Beta: 0.014 Steps:   4 Acce: 0.517
# Stage:   4 Beta: 0.387 Steps:   6 Acce: 0.328
# Stage:   5 Beta: 1.000 Steps:  11 Acce: 0.234
# Sample initial stage: ...
# Stage:   0 Beta: 0.013 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.016 Steps:  25 Acce: 0.663
# Stage:   2 Beta: 0.017 Steps:   4 Acce: 0.545
# Stage:   3 Beta: 0.018 Steps:   5 Acce: 0.490
# Stage:   4 Beta: 0.188 Steps:   6 Acce: 0.365
# Stage:   5 Beta: 1.000 Steps:  10 Acce: 0.227
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.710
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.467
# Stage:   3 Beta: 0.014 Steps:   7 Acce: 0.496
# Stage:   4 Beta: 0.146 Steps:   6 Acce: 0.402
# Stage:   5 Beta: 0.957 Steps:   8 Acce: 0.219
# Stage:   6 Beta: 1.000 Steps:  18 Acce: 0.228
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.662
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.517
# Stage:   3 Beta: 0.015 Steps:   6 Acce: 0.525
# Stage:   4 Beta: 0.418 Steps:   6 Acce: 0.375
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.162
# Sample initial stage: ...
# Stage:   0 Beta: 0.012 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.016 Steps:  25 Acce: 0.658
# Stage:   2 Beta: 0.017 Steps:   4 Acce: 0.522
# Stage:   3 Beta: 0.018 Steps:   6 Acce: 0.453
# Stage:   4 Beta: 0.078 Steps:   7 Acce: 0.310
# Stage:   5 Beta: 0.678 Steps:  12 Acce: 0.313
# Stage:   6 Beta: 1.000 Steps:  12 Acce: 0.280
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.674
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.550
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.536
# Stage:   4 Beta: 0.216 Steps:   5 Acce: 0.468
# Stage:   5 Beta: 1.000 Steps:   7 Acce: 0.159
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.692
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.593
# Stage:   3 Beta: 0.019 Steps:   5 Acce: 0.586
# Stage:   4 Beta: 0.274 Steps:   5 Acce: 0.380
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.191
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.666
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.642
# Stage:   3 Beta: 0.014 Steps:   4 Acce: 0.588
# Stage:   4 Beta: 0.448 Steps:   5 Acce: 0.424
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.165
# Sample initial stage: ...
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.710
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.583
# Stage:   3 Beta: 0.020 Steps:   5 Acce: 0.550
# Stage:   4 Beta: 0.128 Steps:   5 Acce: 0.288
# Stage:   5 Beta: 0.888 Steps:  13 Acce: 0.264
# Stage:   6 Beta: 1.000 Steps:  15 Acce: 0.234
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# Stage:   0 Beta: 0.019 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.026 Steps:  25 Acce: 0.606
# Stage:   2 Beta: 0.028 Steps:   4 Acce: 0.502
# Stage:   3 Beta: 0.028 Steps:   6 Acce: 0.475
# Stage:   4 Beta: 0.095 Steps:   7 Acce: 0.390
# Stage:   5 Beta: 0.691 Steps:   9 Acce: 0.247
# Stage:   6 Beta: 1.000 Steps:  16 Acce: 0.255
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.684
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.497
# Stage:   3 Beta: 0.024 Steps:   6 Acce: 0.533
# Stage:   4 Beta: 0.348 Steps:   6 Acce: 0.355
# Stage:   5 Beta: 1.000 Steps:  10 Acce: 0.280
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.706
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.510
# Stage:   3 Beta: 0.016 Steps:   6 Acce: 0.492
# Stage:   4 Beta: 0.698 Steps:   6 Acce: 0.330
# Stage:   5 Beta: 1.000 Steps:  11 Acce: 0.209
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.646
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.590
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.462
# Stage:   4 Beta: 0.217 Steps:   7 Acce: 0.376
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.253
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.632
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.537
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.504
# Stage:   4 Beta: 0.123 Steps:   6 Acce: 0.363
# Stage:   5 Beta: 0.754 Steps:  10 Acce: 0.235
# Stage:   6 Beta: 1.000 Steps:  17 Acce: 0.263
# Sample initial stage: ...
# Stage:   0 Beta: 0.013 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.016 Steps:  25 Acce: 0.632
# Stage:   2 Beta: 0.017 Steps:   4 Acce: 0.507
# Stage:   3 Beta: 0.018 Steps:   6 Acce: 0.558
# Stage:   4 Beta: 0.514 Steps:   5 Acce: 0.382
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.161
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.678
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.588
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.500
# Stage:   4 Beta: 0.088 Steps:   6 Acce: 0.352
# Stage:   5 Beta: 0.506 Steps:  10 Acce: 0.229
# Stage:   6 Beta: 1.000 Steps:  17 Acce: 0.257
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.009 Steps:  25 Acce: 0.710
# Stage:   2 Beta: 0.010 Steps:   3 Acce: 0.523
# Stage:   3 Beta: 0.076 Steps:   6 Acce: 0.518
# Stage:   4 Beta: 1.000 Steps:   6 Acce: 0.252
# Sample initial stage: ...
# Stage:   0 Beta: 0.017 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.020 Steps:  25 Acce: 0.608
# Stage:   2 Beta: 0.021 Steps:   4 Acce: 0.520
# Stage:   3 Beta: 0.022 Steps:   6 Acce: 0.503
# Stage:   4 Beta: 0.285 Steps:   6 Acce: 0.397
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.228
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.708
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.493
# Stage:   3 Beta: 0.019 Steps:   6 Acce: 0.515
# Stage:   4 Beta: 0.182 Steps:   6 Acce: 0.375
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.272
# Sample initial stage: ...
# Stage:   0 Beta: 0.016 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.019 Steps:  25 Acce: 0.572
# Stage:   2 Beta: 0.020 Steps:   5 Acce: 0.534
# Stage:   3 Beta: 0.022 Steps:   6 Acce: 0.487
# Stage:   4 Beta: 0.609 Steps:   6 Acce: 0.447
# Stage:   5 Beta: 1.000 Steps:   7 Acce: 0.234
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.658
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.568
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.524
# Stage:   4 Beta: 0.202 Steps:   6 Acce: 0.382
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.237
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.653
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.512
# Stage:   3 Beta: 0.038 Steps:   6 Acce: 0.578
# Stage:   4 Beta: 0.636 Steps:   5 Acce: 0.240
# Stage:   5 Beta: 1.000 Steps:  16 Acce: 0.207
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.683
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.590
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.494
# Stage:   4 Beta: 0.339 Steps:   6 Acce: 0.375
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.204
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.662
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.537
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.550
# Stage:   4 Beta: 0.225 Steps:   5 Acce: 0.282
# Stage:   5 Beta: 1.000 Steps:  13 Acce: 0.224
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.664
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.482
# Stage:   3 Beta: 0.014 Steps:   6 Acce: 0.533
# Stage:   4 Beta: 0.573 Steps:   6 Acce: 0.437
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.241
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.711
# Stage:   2 Beta: 0.010 Steps:   3 Acce: 0.490
# Stage:   3 Beta: 0.015 Steps:   6 Acce: 0.532
# Stage:   4 Beta: 0.104 Steps:   6 Acce: 0.320
# Stage:   5 Beta: 0.756 Steps:  11 Acce: 0.387
# Stage:   6 Beta: 1.000 Steps:   9 Acce: 0.289
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.655
# Stage:   2 Beta: 0.015 Steps:   4 Acce: 0.552
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.524
# Stage:   4 Beta: 0.155 Steps:   6 Acce: 0.400
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.250
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.687
# Stage:   2 Beta: 0.014 Steps:   3 Acce: 0.483
# Stage:   3 Beta: 0.014 Steps:   6 Acce: 0.495
# Stage:   4 Beta: 0.146 Steps:   6 Acce: 0.467
# Stage:   5 Beta: 0.957 Steps:   7 Acce: 0.249
# Stage:   6 Beta: 1.000 Steps:  16 Acce: 0.225
# Sample initial stage: ...
# Stage:   0 Beta: 0.012 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.583
# Stage:   2 Beta: 0.015 Steps:   5 Acce: 0.600
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.482
# Stage:   4 Beta: 0.101 Steps:   7 Acce: 0.316
# Stage:   5 Beta: 0.576 Steps:  12 Acce: 0.327
# Stage:   6 Beta: 1.000 Steps:  11 Acce: 0.246
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.691
# Stage:   2 Beta: 0.015 Steps:   3 Acce: 0.533
# Stage:   3 Beta: 0.016 Steps:   6 Acce: 0.510
# Stage:   4 Beta: 0.105 Steps:   6 Acce: 0.298
# Stage:   5 Beta: 0.623 Steps:  12 Acce: 0.344
# Stage:   6 Beta: 1.000 Steps:  10 Acce: 0.261
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.015 Steps:  25 Acce: 0.665
# Stage:   2 Beta: 0.015 Steps:   4 Acce: 0.530
# Stage:   3 Beta: 0.017 Steps:   6 Acce: 0.547
# Stage:   4 Beta: 0.094 Steps:   5 Acce: 0.300
# Stage:   5 Beta: 0.496 Steps:  12 Acce: 0.298
# Stage:   6 Beta: 1.000 Steps:  12 Acce: 0.244
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.690
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.527
# Stage:   3 Beta: 0.028 Steps:   6 Acce: 0.443
# Stage:   4 Beta: 0.152 Steps:   7 Acce: 0.263
# Stage:   5 Beta: 0.816 Steps:  15 Acce: 0.348
# Stage:   6 Beta: 1.000 Steps:  10 Acce: 0.262
# Sample initial stage: ...
# Stage:   0 Beta: 0.014 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.017 Steps:  25 Acce: 0.609
# Stage:   2 Beta: 0.018 Steps:   4 Acce: 0.537
# Stage:   3 Beta: 0.019 Steps:   5 Acce: 0.532
# Stage:   4 Beta: 0.150 Steps:   6 Acce: 0.343
# Stage:   5 Beta: 1.000 Steps:  10 Acce: 0.244
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.678
# Stage:   2 Beta: 0.015 Steps:   4 Acce: 0.615
# Stage:   3 Beta: 0.015 Steps:   4 Acce: 0.507
# Stage:   4 Beta: 0.263 Steps:   6 Acce: 0.432
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.182
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.662
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.547
# Stage:   3 Beta: 0.045 Steps:   5 Acce: 0.492
# Stage:   4 Beta: 0.229 Steps:   6 Acce: 0.268
# Stage:   5 Beta: 1.000 Steps:  14 Acce: 0.321
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.685
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.550
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.504
# Stage:   4 Beta: 0.122 Steps:   6 Acce: 0.355
# Stage:   5 Beta: 0.768 Steps:  10 Acce: 0.226
# Stage:   6 Beta: 1.000 Steps:  17 Acce: 0.213
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.653
# Stage:   2 Beta: 0.015 Steps:   4 Acce: 0.537
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.490
# Stage:   4 Beta: 0.884 Steps:   6 Acce: 0.387
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.158
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.745
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.570
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.512
# Stage:   4 Beta: 0.079 Steps:   6 Acce: 0.333
# Stage:   5 Beta: 0.454 Steps:  11 Acce: 0.205
# Stage:   6 Beta: 1.000 Steps:  20 Acce: 0.283
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.707
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.593
# Stage:   3 Beta: 0.036 Steps:   5 Acce: 0.494
# Stage:   4 Beta: 0.466 Steps:   6 Acce: 0.182
# Stage:   5 Beta: 1.000 Steps:  22 Acce: 0.206
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.687
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.530
# Stage:   3 Beta: 0.013 Steps:   6 Acce: 0.520
# Stage:   4 Beta: 0.122 Steps:   6 Acce: 0.448
# Stage:   5 Beta: 0.709 Steps:   7 Acce: 0.333
# Stage:   6 Beta: 1.000 Steps:  11 Acce: 0.219
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.668
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.525
# Stage:   3 Beta: 0.040 Steps:   6 Acce: 0.533
# Stage:   4 Beta: 0.515 Steps:   6 Acce: 0.323
# Stage:   5 Beta: 1.000 Steps:  11 Acce: 0.271
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.691
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.640
# Stage:   3 Beta: 0.013 Steps:   4 Acce: 0.560
# Stage:   4 Beta: 0.071 Steps:   5 Acce: 0.250
# Stage:   5 Beta: 0.357 Steps:  16 Acce: 0.233
# Stage:   6 Beta: 1.000 Steps:  17 Acce: 0.255
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.700
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.537
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.552
# Stage:   4 Beta: 0.239 Steps:   5 Acce: 0.282
# Stage:   5 Beta: 1.000 Steps:  13 Acce: 0.228
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.702
# Stage:   2 Beta: 0.010 Steps:   3 Acce: 0.647
# Stage:   3 Beta: 0.018 Steps:   4 Acce: 0.495
# Stage:   4 Beta: 0.498 Steps:   6 Acce: 0.387
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.141
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.681
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.522
# Stage:   3 Beta: 0.042 Steps:   6 Acce: 0.467
# Stage:   4 Beta: 0.363 Steps:   7 Acce: 0.379
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.251
# Sample initial stage: ...
# Stage:   0 Beta: 0.025 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.030 Steps:  25 Acce: 0.546
# Stage:   2 Beta: 0.031 Steps:   5 Acce: 0.460
# Stage:   3 Beta: 0.032 Steps:   7 Acce: 0.523
# Stage:   4 Beta: 0.270 Steps:   6 Acce: 0.547
# Stage:   5 Beta: 1.000 Steps:   5 Acce: 0.224
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.709
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.577
# Stage:   3 Beta: 0.028 Steps:   5 Acce: 0.520
# Stage:   4 Beta: 0.182 Steps:   6 Acce: 0.272
# Stage:   5 Beta: 1.000 Steps:  14 Acce: 0.236
# Sample initial stage: ...
# Stage:   0 Beta: 0.020 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.023 Steps:  25 Acce: 0.592
# Stage:   2 Beta: 0.024 Steps:   5 Acce: 0.530
# Stage:   3 Beta: 0.025 Steps:   6 Acce: 0.545
# Stage:   4 Beta: 0.156 Steps:   5 Acce: 0.274
# Stage:   5 Beta: 1.000 Steps:  14 Acce: 0.339
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.704
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.600
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.460
# Stage:   4 Beta: 0.072 Steps:   7 Acce: 0.269
# Stage:   5 Beta: 0.690 Steps:  14 Acce: 0.258
# Stage:   6 Beta: 1.000 Steps:  15 Acce: 0.247
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.678
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.555
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.508
# Stage:   4 Beta: 0.133 Steps:   6 Acce: 0.287
# Stage:   5 Beta: 1.000 Steps:  13 Acce: 0.229
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.692
# Stage:   2 Beta: 0.013 Steps:   3 Acce: 0.550
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.448
# Stage:   4 Beta: 0.076 Steps:   7 Acce: 0.337
# Stage:   5 Beta: 0.452 Steps:  11 Acce: 0.252
# Stage:   6 Beta: 1.000 Steps:  15 Acce: 0.258
# Sample initial stage: ...
# Stage:   0 Beta: 0.014 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.017 Steps:  25 Acce: 0.587
# Stage:   2 Beta: 0.017 Steps:   5 Acce: 0.558
# Stage:   3 Beta: 0.024 Steps:   5 Acce: 0.518
# Stage:   4 Beta: 0.549 Steps:   6 Acce: 0.507
# Stage:   5 Beta: 1.000 Steps:   6 Acce: 0.160
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.650
# Stage:   2 Beta: 0.011 Steps:   4 Acce: 0.600
# Stage:   3 Beta: 0.027 Steps:   5 Acce: 0.496
# Stage:   4 Beta: 0.158 Steps:   6 Acce: 0.300
# Stage:   5 Beta: 0.705 Steps:  12 Acce: 0.282
# Stage:   6 Beta: 1.000 Steps:  13 Acce: 0.303
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.684
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.522
# Stage:   3 Beta: 0.021 Steps:   6 Acce: 0.568
# Stage:   4 Beta: 0.152 Steps:   5 Acce: 0.258
# Stage:   5 Beta: 0.961 Steps:  15 Acce: 0.293
# Stage:   6 Beta: 1.000 Steps:  13 Acce: 0.282
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.724
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.597
# Stage:   3 Beta: 0.022 Steps:   5 Acce: 0.484
# Stage:   4 Beta: 0.165 Steps:   6 Acce: 0.348
# Stage:   5 Beta: 0.796 Steps:  10 Acce: 0.228
# Stage:   6 Beta: 1.000 Steps:  17 Acce: 0.213
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.689
# Stage:   2 Beta: 0.014 Steps:   3 Acce: 0.600
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.538
# Stage:   4 Beta: 0.151 Steps:   5 Acce: 0.306
# Stage:   5 Beta: 1.000 Steps:  12 Acce: 0.243
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.672
# Stage:   2 Beta: 0.010 Steps:   4 Acce: 0.468
# Stage:   3 Beta: 0.135 Steps:   7 Acce: 0.566
# Stage:   4 Beta: 0.951 Steps:   5 Acce: 0.230
# Stage:   5 Beta: 1.000 Steps:  17 Acce: 0.369
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.697
# Stage:   2 Beta: 0.013 Steps:   3 Acce: 0.560
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.514
# Stage:   4 Beta: 0.097 Steps:   6 Acce: 0.327
# Stage:   5 Beta: 0.989 Steps:  11 Acce: 0.250
# Stage:   6 Beta: 1.000 Steps:  16 Acce: 0.331
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.730
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.513
# Stage:   3 Beta: 0.013 Steps:   6 Acce: 0.477
# Stage:   4 Beta: 0.161 Steps:   7 Acce: 0.287
# Stage:   5 Beta: 0.937 Steps:  13 Acce: 0.214
# Stage:   6 Beta: 1.000 Steps:  19 Acce: 0.225
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.631
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.515
# Stage:   3 Beta: 0.022 Steps:   6 Acce: 0.518
# Stage:   4 Beta: 0.532 Steps:   6 Acce: 0.368
# Stage:   5 Beta: 1.000 Steps:  10 Acce: 0.227
# Sample initial stage: ...
# Stage:   0 Beta: 0.012 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.638
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.527
# Stage:   3 Beta: 0.033 Steps:   6 Acce: 0.483
# Stage:   4 Beta: 0.356 Steps:   6 Acce: 0.323
# Stage:   5 Beta: 1.000 Steps:  11 Acce: 0.299
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.671
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.545
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.494
# Stage:   4 Beta: 0.115 Steps:   6 Acce: 0.335
# Stage:   5 Beta: 0.616 Steps:  11 Acce: 0.243
# Stage:   6 Beta: 1.000 Steps:  16 Acce: 0.276
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.655
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.560
# Stage:   3 Beta: 0.040 Steps:   5 Acce: 0.510
# Stage:   4 Beta: 0.269 Steps:   6 Acce: 0.272
# Stage:   5 Beta: 1.000 Steps:  14 Acce: 0.326
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.670
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.560
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.506
# Stage:   4 Beta: 0.262 Steps:   6 Acce: 0.457
# Stage:   5 Beta: 1.000 Steps:   7 Acce: 0.247
# Sample initial stage: ...
# Stage:   0 Beta: 0.014 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.016 Steps:  25 Acce: 0.650
# Stage:   2 Beta: 0.016 Steps:   4 Acce: 0.525
# Stage:   3 Beta: 0.018 Steps:   6 Acce: 0.518
# Stage:   4 Beta: 0.265 Steps:   6 Acce: 0.437
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.281
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.705
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.540
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.510
# Stage:   4 Beta: 0.090 Steps:   6 Acce: 0.343
# Stage:   5 Beta: 0.627 Steps:  10 Acce: 0.315
# Stage:   6 Beta: 1.000 Steps:  12 Acce: 0.255
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.730
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.617
# Stage:   3 Beta: 0.012 Steps:   4 Acce: 0.507
# Stage:   4 Beta: 0.385 Steps:   6 Acce: 0.328
# Stage:   5 Beta: 1.000 Steps:  11 Acce: 0.184
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.726
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.563
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.514
# Stage:   4 Beta: 0.087 Steps:   6 Acce: 0.253
# Stage:   5 Beta: 0.625 Steps:  15 Acce: 0.303
# Stage:   6 Beta: 1.000 Steps:  12 Acce: 0.237
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.684
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.552
# Stage:   3 Beta: 0.056 Steps:   5 Acce: 0.458
# Stage:   4 Beta: 0.292 Steps:   7 Acce: 0.307
# Stage:   5 Beta: 1.000 Steps:  12 Acce: 0.296
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.660
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.542
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.528
# Stage:   4 Beta: 0.167 Steps:   6 Acce: 0.290
# Stage:   5 Beta: 0.912 Steps:  13 Acce: 0.242
# Stage:   6 Beta: 1.000 Steps:  16 Acce: 0.246
# Sample initial stage: ...
# Stage:   0 Beta: 0.021 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.029 Steps:  25 Acce: 0.679
# Stage:   2 Beta: 0.032 Steps:   4 Acce: 0.357
# Stage:   3 Beta: 0.033 Steps:  10 Acce: 0.498
# Stage:   4 Beta: 0.202 Steps:   6 Acce: 0.465
# Stage:   5 Beta: 1.000 Steps:   7 Acce: 0.250
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.655
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.570
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.494
# Stage:   4 Beta: 0.122 Steps:   6 Acce: 0.353
# Stage:   5 Beta: 1.000 Steps:  10 Acce: 0.276
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.664
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.547
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.526
# Stage:   4 Beta: 0.293 Steps:   6 Acce: 0.432
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.204
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.010 Steps:  25 Acce: 0.695
# Stage:   2 Beta: 0.010 Steps:   3 Acce: 0.620
# Stage:   3 Beta: 0.013 Steps:   4 Acce: 0.542
# Stage:   4 Beta: 0.153 Steps:   5 Acce: 0.306
# Stage:   5 Beta: 1.000 Steps:  12 Acce: 0.252
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.703
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.597
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.514
# Stage:   4 Beta: 0.386 Steps:   6 Acce: 0.352
# Stage:   5 Beta: 1.000 Steps:  10 Acce: 0.166
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.688
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.533
# Stage:   3 Beta: 0.075 Steps:   6 Acce: 0.532
# Stage:   4 Beta: 0.586 Steps:   6 Acce: 0.198
# Stage:   5 Beta: 1.000 Steps:  20 Acce: 0.258
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.680
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.487
# Stage:   3 Beta: 0.083 Steps:   6 Acce: 0.467
# Stage:   4 Beta: 0.667 Steps:   7 Acce: 0.281
# Stage:   5 Beta: 1.000 Steps:  13 Acce: 0.386
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.676
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.542
# Stage:   3 Beta: 0.021 Steps:   5 Acce: 0.462
# Stage:   4 Beta: 0.145 Steps:   7 Acce: 0.410
# Stage:   5 Beta: 0.898 Steps:   8 Acce: 0.212
# Stage:   6 Beta: 1.000 Steps:  19 Acce: 0.224
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.618
# Stage:   2 Beta: 0.014 Steps:   4 Acce: 0.485
# Stage:   3 Beta: 0.015 Steps:   6 Acce: 0.515
# Stage:   4 Beta: 0.108 Steps:   6 Acce: 0.353
# Stage:   5 Beta: 0.729 Steps:  10 Acce: 0.360
# Stage:   6 Beta: 1.000 Steps:  10 Acce: 0.322
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.665
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.557
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.532
# Stage:   4 Beta: 0.168 Steps:   6 Acce: 0.375
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.222
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.704
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.587
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.504
# Stage:   4 Beta: 0.140 Steps:   6 Acce: 0.347
# Stage:   5 Beta: 0.925 Steps:  10 Acce: 0.302
# Stage:   6 Beta: 1.000 Steps:  12 Acce: 0.247
# Sample initial stage: ...
# Stage:   0 Beta: 0.014 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.017 Steps:  25 Acce: 0.618
# Stage:   2 Beta: 0.017 Steps:   4 Acce: 0.555
# Stage:   3 Beta: 0.022 Steps:   5 Acce: 0.520
# Stage:   4 Beta: 0.208 Steps:   6 Acce: 0.412
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.281
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.713
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.510
# Stage:   3 Beta: 0.025 Steps:   6 Acce: 0.498
# Stage:   4 Beta: 0.179 Steps:   6 Acce: 0.370
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.272
# Sample initial stage: ...
# Stage:   0 Beta: 0.012 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.015 Steps:  25 Acce: 0.640
# Stage:   2 Beta: 0.015 Steps:   4 Acce: 0.540
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.484
# Stage:   4 Beta: 0.065 Steps:   6 Acce: 0.317
# Stage:   5 Beta: 0.405 Steps:  12 Acce: 0.290
# Stage:   6 Beta: 1.000 Steps:  13 Acce: 0.275
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.679
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.605
# Stage:   3 Beta: 0.014 Steps:   4 Acce: 0.490
# Stage:   4 Beta: 0.324 Steps:   6 Acce: 0.407
# Stage:   5 Beta: 1.000 Steps:   8 Acce: 0.190
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.666
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.490
# Stage:   3 Beta: 0.027 Steps:   6 Acce: 0.543
# Stage:   4 Beta: 0.212 Steps:   5 Acce: 0.316
# Stage:   5 Beta: 1.000 Steps:  12 Acce: 0.278
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.641
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.540
# Stage:   3 Beta: 0.021 Steps:   5 Acce: 0.548
# Stage:   4 Beta: 0.763 Steps:   5 Acce: 0.290
# Stage:   5 Beta: 1.000 Steps:  13 Acce: 0.235
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.014 Steps:  25 Acce: 0.681
# Stage:   2 Beta: 0.015 Steps:   4 Acce: 0.585
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.500
# Stage:   4 Beta: 0.450 Steps:   6 Acce: 0.287
# Stage:   5 Beta: 1.000 Steps:  13 Acce: 0.164
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.677
# Stage:   2 Beta: 0.012 Steps:   4 Acce: 0.552
# Stage:   3 Beta: 0.021 Steps:   5 Acce: 0.536
# Stage:   4 Beta: 1.000 Steps:   5 Acce: 0.342
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.012 Steps:  25 Acce: 0.704
# Stage:   2 Beta: 0.012 Steps:   3 Acce: 0.577
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.514
# Stage:   4 Beta: 0.401 Steps:   6 Acce: 0.383
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.270
# Sample initial stage: ...
# Stage:   0 Beta: 0.010 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.652
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.560
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.526
# Stage:   4 Beta: 0.097 Steps:   6 Acce: 0.228
# Stage:   5 Beta: 0.706 Steps:  17 Acce: 0.310
# Stage:   6 Beta: 1.000 Steps:  12 Acce: 0.270
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.677
# Stage:   2 Beta: 0.011 Steps:   4 Acce: 0.552
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.494
# Stage:   4 Beta: 0.083 Steps:   6 Acce: 0.317
# Stage:   5 Beta: 0.592 Steps:  12 Acce: 0.233
# Stage:   6 Beta: 1.000 Steps:  17 Acce: 0.295
# Sample initial stage: ...
# Stage:   0 Beta: 0.011 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.013 Steps:  25 Acce: 0.640
# Stage:   2 Beta: 0.013 Steps:   4 Acce: 0.510
# Stage:   3 Beta: 0.030 Steps:   6 Acce: 0.498
# Stage:   4 Beta: 0.584 Steps:   6 Acce: 0.382
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.307
# Sample initial stage: ...
# Stage:   0 Beta: 0.013 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.015 Steps:  25 Acce: 0.620
# Stage:   2 Beta: 0.015 Steps:   4 Acce: 0.502
# Stage:   3 Beta: 0.058 Steps:   6 Acce: 0.550
# Stage:   4 Beta: 0.665 Steps:   5 Acce: 0.362
# Stage:   5 Beta: 1.000 Steps:  10 Acce: 0.310
# Sample initial stage: ...
# Stage:   0 Beta: 0.008 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.697
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.547
# Stage:   3 Beta: 0.012 Steps:   5 Acce: 0.550
# Stage:   4 Beta: 0.276 Steps:   5 Acce: 0.390
# Stage:   5 Beta: 1.000 Steps:   9 Acce: 0.254
# Sample initial stage: ...
# Stage:   0 Beta: 0.009 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.011 Steps:  25 Acce: 0.690
# Stage:   2 Beta: 0.011 Steps:   3 Acce: 0.600
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.514
# Stage:   4 Beta: 0.090 Steps:   6 Acce: 0.315
# Stage:   5 Beta: 0.568 Steps:  12 Acce: 0.268
# Stage:   6 Beta: 1.000 Steps:  14 Acce: 0.292

# %%
## simulation
num = min(Bdata.shape[0], 100)
draws = 1000
postSimR0 = np.zeros((num, draws))
postSimM  = np.zeros((num, draws))

for i in range(num):
    with pm.Model() as ncov_model:
    
        # Priors
        r0 = pm.Uniform('r0', lower=1, upper=10)
        mul= pm.Uniform('mul', lower=1e-5, upper=1-1e-5)

        out = th_forward_modelv2(r0, mul)
        lam = out[tuple(tb[:,0]), 5] - out[tuple(tb[:,0]-1), 5]
        # data:observed=tb[:,1]
        JoWu = pm.Poisson('xpted', mu=lam, observed=Pdata[i,])
        # data:evRel[:,2]
        Evac = pm.Binomial('exv', n=evRel[:,1], 
                           p=(out[tuple(evRel[:,0]), 1] 
                              + out[tuple(evRel[:,0]), 2]
                             )/(out[tuple(evRel[:,0]), 0] + out[tuple(evRel[:,0]), 1] + out[tuple(evRel[:,0]), 4] 
                              + out[tuple(evRel[:,0]), 2]
                               ), observed = Bdata[i,])

        trace = pm.sample_smc(draws, start=startsmc, parallel=True, cores = 8)
        postSimR0[i,:] = trace.get_values('r0')
        postSimM[i,:]  = trace.get_values('mul')
# Out:
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.744
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.603
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.275
# Stage:   4 Beta: 0.052 Steps:  14 Acce: 0.166
# Stage:   5 Beta: 0.600 Steps:  25 Acce: 0.029
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.075
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.743
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.540
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.338
# Stage:   4 Beta: 0.065 Steps:  11 Acce: 0.284
# Stage:   5 Beta: 0.220 Steps:  13 Acce: 0.102
# Stage:   6 Beta: 0.547 Steps:  25 Acce: 0.066
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.037
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.748
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.610
# Stage:   3 Beta: 0.015 Steps:   4 Acce: 0.362
# Stage:   4 Beta: 0.016 Steps:  10 Acce: 0.204
# Stage:   5 Beta: 0.295 Steps:  20 Acce: 0.075
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.076
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.782
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.563
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.292
# Stage:   4 Beta: 0.194 Steps:  13 Acce: 0.268
# Stage:   5 Beta: 1.000 Steps:  14 Acce: 0.082
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.777
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.587
# Stage:   3 Beta: 0.005 Steps:   5 Acce: 0.300
# Stage:   4 Beta: 0.138 Steps:  12 Acce: 0.217
# Stage:   5 Beta: 1.000 Steps:  18 Acce: 0.051
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.752
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.630
# Stage:   3 Beta: 0.011 Steps:   4 Acce: 0.370
# Stage:   4 Beta: 0.011 Steps:   9 Acce: 0.267
# Stage:   5 Beta: 0.140 Steps:  14 Acce: 0.061
# Stage:   6 Beta: 0.634 Steps:  25 Acce: 0.059
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.050
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.750
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.623
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.350
# Stage:   4 Beta: 0.085 Steps:  10 Acce: 0.232
# Stage:   5 Beta: 0.623 Steps:  17 Acce: 0.058
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.064
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.767
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.640
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.292
# Stage:   4 Beta: 0.053 Steps:  13 Acce: 0.246
# Stage:   5 Beta: 1.000 Steps:  16 Acce: 0.074
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.763
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.553
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.334
# Stage:   4 Beta: 0.036 Steps:  11 Acce: 0.247
# Stage:   5 Beta: 0.205 Steps:  16 Acce: 0.069
# Stage:   6 Beta: 0.822 Steps:  25 Acce: 0.087
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.058
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.764
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.607
# Stage:   3 Beta: 0.012 Steps:   4 Acce: 0.323
# Stage:   4 Beta: 0.013 Steps:  11 Acce: 0.202
# Stage:   5 Beta: 0.277 Steps:  20 Acce: 0.085
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.059
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.745
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.593
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.358
# Stage:   4 Beta: 0.014 Steps:  10 Acce: 0.177
# Stage:   5 Beta: 0.149 Steps:  23 Acce: 0.072
# Stage:   6 Beta: 0.670 Steps:  25 Acce: 0.060
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.070
# Sample initial stage: ...
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.751
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.637
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.285
# Stage:   4 Beta: 0.084 Steps:  13 Acce: 0.221
# Stage:   5 Beta: 0.833 Steps:  18 Acce: 0.075
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.126
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.737
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.590
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.282
# Stage:   4 Beta: 0.043 Steps:  13 Acce: 0.196
# Stage:   5 Beta: 0.242 Steps:  21 Acce: 0.078
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.093
# /usr/local/lib/python3.7/dist-packages/theano/tensor/subtensor.py:2197: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   rval = inputs[0].__getitem__(inputs[1:])
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.752
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.673
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.407
# Stage:   4 Beta: 0.053 Steps:   8 Acce: 0.250
# Stage:   5 Beta: 0.251 Steps:  16 Acce: 0.039
# Stage:   6 Beta: 0.839 Steps:  25 Acce: 0.047
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.056
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.738
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.577
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.302
# Stage:   4 Beta: 0.157 Steps:  12 Acce: 0.241
# Stage:   5 Beta: 0.935 Steps:  16 Acce: 0.062
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.092
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.736
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.573
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.296
# Stage:   4 Beta: 0.085 Steps:  13 Acce: 0.275
# Stage:   5 Beta: 1.000 Steps:  14 Acce: 0.087
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.750
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.623
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.310
# Stage:   4 Beta: 0.087 Steps:  12 Acce: 0.230
# Stage:   5 Beta: 0.506 Steps:  17 Acce: 0.048
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.036
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.727
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.653
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.265
# Stage:   4 Beta: 0.100 Steps:  14 Acce: 0.137
# Stage:   5 Beta: 0.530 Steps:  25 Acce: 0.063
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.117
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.790
# Stage:   2 Beta: 0.006 Steps:   2 Acce: 0.575
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.298
# Stage:   4 Beta: 0.014 Steps:  13 Acce: 0.216
# Stage:   5 Beta: 0.169 Steps:  18 Acce: 0.057
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.095
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.770
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.617
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.330
# Stage:   4 Beta: 0.077 Steps:  11 Acce: 0.236
# Stage:   5 Beta: 0.325 Steps:  17 Acce: 0.060
# Stage:   6 Beta: 0.855 Steps:  25 Acce: 0.050
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.048
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.760
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.637
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.355
# Stage:   4 Beta: 0.286 Steps:  10 Acce: 0.196
# Stage:   5 Beta: 1.000 Steps:  21 Acce: 0.051
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.761
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.573
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.336
# Stage:   4 Beta: 0.096 Steps:  11 Acce: 0.195
# Stage:   5 Beta: 0.988 Steps:  21 Acce: 0.084
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.124
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.748
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.553
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.360
# Stage:   4 Beta: 0.044 Steps:  10 Acce: 0.253
# Stage:   5 Beta: 0.174 Steps:  15 Acce: 0.078
# Stage:   6 Beta: 0.716 Steps:  25 Acce: 0.054
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.057
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.756
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.540
# Stage:   3 Beta: 0.014 Steps:   5 Acce: 0.314
# Stage:   4 Beta: 0.014 Steps:  12 Acce: 0.180
# Stage:   5 Beta: 0.200 Steps:  23 Acce: 0.097
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.082
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.730
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.560
# Stage:   3 Beta: 0.005 Steps:   5 Acce: 0.322
# Stage:   4 Beta: 0.185 Steps:  11 Acce: 0.195
# Stage:   5 Beta: 1.000 Steps:  21 Acce: 0.040
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.740
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.633
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.300
# Stage:   4 Beta: 0.115 Steps:  12 Acce: 0.198
# Stage:   5 Beta: 1.000 Steps:  20 Acce: 0.085
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.749
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.557
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.280
# Stage:   4 Beta: 0.185 Steps:  14 Acce: 0.174
# Stage:   5 Beta: 0.880 Steps:  24 Acce: 0.072
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.079
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.753
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.573
# Stage:   3 Beta: 0.008 Steps:   5 Acce: 0.346
# Stage:   4 Beta: 0.062 Steps:  10 Acce: 0.274
# Stage:   5 Beta: 0.486 Steps:  14 Acce: 0.077
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.054
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.746
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.670
# Stage:   3 Beta: 0.014 Steps:   4 Acce: 0.323
# Stage:   4 Beta: 0.015 Steps:  11 Acce: 0.237
# Stage:   5 Beta: 0.356 Steps:  17 Acce: 0.061
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.058
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.735
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.600
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.282
# Stage:   4 Beta: 0.039 Steps:  13 Acce: 0.169
# Stage:   5 Beta: 0.215 Steps:  24 Acce: 0.040
# Stage:   6 Beta: 0.731 Steps:  25 Acce: 0.078
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.051
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.767
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.560
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.300
# Stage:   4 Beta: 0.131 Steps:  12 Acce: 0.208
# Stage:   5 Beta: 0.744 Steps:  19 Acce: 0.066
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.053
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.737
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.547
# Stage:   3 Beta: 0.011 Steps:   5 Acce: 0.388
# Stage:   4 Beta: 0.025 Steps:   9 Acce: 0.254
# Stage:   5 Beta: 0.218 Steps:  15 Acce: 0.041
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.031
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.748
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.533
# Stage:   3 Beta: 0.012 Steps:   6 Acce: 0.367
# Stage:   4 Beta: 0.012 Steps:  10 Acce: 0.231
# Stage:   5 Beta: 0.063 Steps:  17 Acce: 0.068
# Stage:   6 Beta: 0.381 Steps:  25 Acce: 0.040
# Stage:   7 Beta: 0.975 Steps:  25 Acce: 0.050
# Stage:   8 Beta: 1.000 Steps:  25 Acce: 0.058
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.733
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.523
# Stage:   3 Beta: 0.006 Steps:   6 Acce: 0.338
# Stage:   4 Beta: 0.051 Steps:  11 Acce: 0.228
# Stage:   5 Beta: 0.257 Steps:  17 Acce: 0.061
# Stage:   6 Beta: 0.992 Steps:  25 Acce: 0.060
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.048
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.743
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.573
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.284
# Stage:   4 Beta: 0.047 Steps:  13 Acce: 0.193
# Stage:   5 Beta: 0.299 Steps:  21 Acce: 0.069
# Stage:   6 Beta: 0.771 Steps:  25 Acce: 0.131
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.079
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.750
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.587
# Stage:   3 Beta: 0.010 Steps:   5 Acce: 0.436
# Stage:   4 Beta: 0.020 Steps:   8 Acce: 0.264
# Stage:   5 Beta: 0.072 Steps:  15 Acce: 0.069
# Stage:   6 Beta: 0.306 Steps:  25 Acce: 0.068
# Stage:   7 Beta: 0.809 Steps:  25 Acce: 0.059
# Stage:   8 Beta: 1.000 Steps:  25 Acce: 0.031
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.760
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.603
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.305
# Stage:   4 Beta: 0.099 Steps:  12 Acce: 0.285
# Stage:   5 Beta: 0.485 Steps:  13 Acce: 0.070
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.086
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.724
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.520
# Stage:   3 Beta: 0.015 Steps:   6 Acce: 0.350
# Stage:   4 Beta: 0.015 Steps:  10 Acce: 0.198
# Stage:   5 Beta: 0.178 Steps:  20 Acce: 0.126
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.068
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.734
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.653
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.403
# Stage:   4 Beta: 0.131 Steps:   8 Acce: 0.279
# Stage:   5 Beta: 0.481 Steps:  14 Acce: 0.046
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.047
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.780
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.643
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.285
# Stage:   4 Beta: 0.062 Steps:  13 Acce: 0.178
# Stage:   5 Beta: 0.289 Steps:  23 Acce: 0.036
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.060
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.790
# Stage:   2 Beta: 0.005 Steps:   2 Acce: 0.605
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.330
# Stage:   4 Beta: 0.091 Steps:  11 Acce: 0.167
# Stage:   5 Beta: 1.000 Steps:  25 Acce: 0.038
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.778
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.597
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.312
# Stage:   4 Beta: 0.029 Steps:  12 Acce: 0.185
# Stage:   5 Beta: 0.152 Steps:  22 Acce: 0.061
# Stage:   6 Beta: 0.730 Steps:  25 Acce: 0.057
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.057
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.742
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.517
# Stage:   3 Beta: 0.006 Steps:   6 Acce: 0.385
# Stage:   4 Beta: 0.084 Steps:   9 Acce: 0.228
# Stage:   5 Beta: 0.772 Steps:  17 Acce: 0.066
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.071
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.766
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.583
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.348
# Stage:   4 Beta: 0.048 Steps:  10 Acce: 0.177
# Stage:   5 Beta: 0.231 Steps:  23 Acce: 0.046
# Stage:   6 Beta: 0.867 Steps:  25 Acce: 0.043
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.028
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.759
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.563
# Stage:   3 Beta: 0.005 Steps:   5 Acce: 0.342
# Stage:   4 Beta: 0.200 Steps:  11 Acce: 0.185
# Stage:   5 Beta: 0.734 Steps:  22 Acce: 0.042
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.044
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.782
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.660
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.292
# Stage:   4 Beta: 0.058 Steps:  13 Acce: 0.188
# Stage:   5 Beta: 0.229 Steps:  22 Acce: 0.035
# Stage:   6 Beta: 0.769 Steps:  25 Acce: 0.036
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.049
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.744
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.630
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.312
# Stage:   4 Beta: 0.115 Steps:  12 Acce: 0.313
# Stage:   5 Beta: 0.675 Steps:  12 Acce: 0.067
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.049
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.752
# Stage:   2 Beta: 0.004 Steps:   3 Acce: 0.553
# Stage:   3 Beta: 0.004 Steps:   5 Acce: 0.262
# Stage:   4 Beta: 0.113 Steps:  15 Acce: 0.094
# Stage:   5 Beta: 1.000 Steps:  25 Acce: 0.072
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.746
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.673
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.340
# Stage:   4 Beta: 0.045 Steps:  11 Acce: 0.184
# Stage:   5 Beta: 0.274 Steps:  22 Acce: 0.056
# Stage:   6 Beta: 0.732 Steps:  25 Acce: 0.048
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.063
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.769
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.620
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.347
# Stage:   4 Beta: 0.163 Steps:  10 Acce: 0.217
# Stage:   5 Beta: 1.000 Steps:  18 Acce: 0.064
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.738
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.610
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.292
# Stage:   4 Beta: 0.077 Steps:  13 Acce: 0.243
# Stage:   5 Beta: 0.393 Steps:  16 Acce: 0.059
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.051
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.757
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.653
# Stage:   3 Beta: 0.014 Steps:   4 Acce: 0.290
# Stage:   4 Beta: 0.015 Steps:  13 Acce: 0.223
# Stage:   5 Beta: 0.092 Steps:  18 Acce: 0.065
# Stage:   6 Beta: 0.554 Steps:  25 Acce: 0.042
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.045
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.734
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.493
# Stage:   3 Beta: 0.015 Steps:   6 Acce: 0.312
# Stage:   4 Beta: 0.015 Steps:  12 Acce: 0.193
# Stage:   5 Beta: 0.085 Steps:  21 Acce: 0.096
# Stage:   6 Beta: 0.369 Steps:  25 Acce: 0.044
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.096
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.729
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.550
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.382
# Stage:   4 Beta: 0.014 Steps:   9 Acce: 0.196
# Stage:   5 Beta: 0.087 Steps:  21 Acce: 0.082
# Stage:   6 Beta: 0.566 Steps:  25 Acce: 0.043
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.056
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.746
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.600
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.304
# Stage:   4 Beta: 0.049 Steps:  12 Acce: 0.218
# Stage:   5 Beta: 0.263 Steps:  18 Acce: 0.044
# Stage:   6 Beta: 0.806 Steps:  25 Acce: 0.052
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.050
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.759
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.613
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.343
# Stage:   4 Beta: 0.146 Steps:  10 Acce: 0.242
# Stage:   5 Beta: 1.000 Steps:  16 Acce: 0.066
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.742
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.517
# Stage:   3 Beta: 0.014 Steps:   6 Acce: 0.315
# Stage:   4 Beta: 0.015 Steps:  12 Acce: 0.186
# Stage:   5 Beta: 0.047 Steps:  22 Acce: 0.068
# Stage:   6 Beta: 0.184 Steps:  25 Acce: 0.053
# Stage:   7 Beta: 0.610 Steps:  25 Acce: 0.108
# Stage:   8 Beta: 1.000 Steps:  25 Acce: 0.116
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.749
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.577
# Stage:   3 Beta: 0.008 Steps:   5 Acce: 0.292
# Stage:   4 Beta: 0.043 Steps:  13 Acce: 0.228
# Stage:   5 Beta: 0.303 Steps:  17 Acce: 0.060
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.044
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.740
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.573
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.302
# Stage:   4 Beta: 0.016 Steps:  12 Acce: 0.181
# Stage:   5 Beta: 0.099 Steps:  23 Acce: 0.037
# Stage:   6 Beta: 0.515 Steps:  25 Acce: 0.062
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.085
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.731
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.570
# Stage:   3 Beta: 0.012 Steps:   5 Acce: 0.416
# Stage:   4 Beta: 0.012 Steps:   8 Acce: 0.171
# Stage:   5 Beta: 0.121 Steps:  24 Acce: 0.084
# Stage:   6 Beta: 0.767 Steps:  25 Acce: 0.084
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.052
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.767
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.523
# Stage:   3 Beta: 0.005 Steps:   6 Acce: 0.340
# Stage:   4 Beta: 0.067 Steps:  11 Acce: 0.225
# Stage:   5 Beta: 0.430 Steps:  18 Acce: 0.059
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.081
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.740
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.593
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.326
# Stage:   4 Beta: 0.014 Steps:  11 Acce: 0.248
# Stage:   5 Beta: 0.084 Steps:  16 Acce: 0.091
# Stage:   6 Beta: 0.413 Steps:  25 Acce: 0.092
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.067
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.764
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.607
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.312
# Stage:   4 Beta: 0.171 Steps:  12 Acce: 0.253
# Stage:   5 Beta: 0.656 Steps:  15 Acce: 0.053
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.072
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.729
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.610
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.370
# Stage:   4 Beta: 0.131 Steps:   9 Acce: 0.243
# Stage:   5 Beta: 0.978 Steps:  16 Acce: 0.052
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.058
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.751
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.627
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.302
# Stage:   4 Beta: 0.061 Steps:  12 Acce: 0.263
# Stage:   5 Beta: 0.501 Steps:  15 Acce: 0.061
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.045
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.786
# Stage:   2 Beta: 0.006 Steps:   2 Acce: 0.665
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.345
# Stage:   4 Beta: 0.047 Steps:  10 Acce: 0.254
# Stage:   5 Beta: 0.322 Steps:  15 Acce: 0.084
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.042
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.773
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.593
# Stage:   3 Beta: 0.005 Steps:   5 Acce: 0.394
# Stage:   4 Beta: 0.040 Steps:   9 Acce: 0.226
# Stage:   5 Beta: 0.178 Steps:  18 Acce: 0.049
# Stage:   6 Beta: 0.605 Steps:  25 Acce: 0.051
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.052
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.768
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.607
# Stage:   3 Beta: 0.010 Steps:   4 Acce: 0.325
# Stage:   4 Beta: 0.042 Steps:  11 Acce: 0.252
# Stage:   5 Beta: 0.248 Steps:  15 Acce: 0.057
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.067
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.735
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.590
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.330
# Stage:   4 Beta: 0.224 Steps:  11 Acce: 0.208
# Stage:   5 Beta: 1.000 Steps:  19 Acce: 0.071
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.743
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.677
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.383
# Stage:   4 Beta: 0.027 Steps:   9 Acce: 0.227
# Stage:   5 Beta: 0.143 Steps:  17 Acce: 0.042
# Stage:   6 Beta: 0.796 Steps:  25 Acce: 0.052
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.081
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.722
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.520
# Stage:   3 Beta: 0.005 Steps:   6 Acce: 0.273
# Stage:   4 Beta: 0.079 Steps:  14 Acce: 0.232
# Stage:   5 Beta: 1.000 Steps:  17 Acce: 0.065
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.754
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.663
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.275
# Stage:   4 Beta: 0.035 Steps:  14 Acce: 0.168
# Stage:   5 Beta: 0.173 Steps:  25 Acce: 0.054
# Stage:   6 Beta: 0.687 Steps:  25 Acce: 0.056
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.048
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.747
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.610
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.295
# Stage:   4 Beta: 0.123 Steps:  13 Acce: 0.185
# Stage:   5 Beta: 0.563 Steps:  22 Acce: 0.052
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.032
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.748
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.620
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.315
# Stage:   4 Beta: 0.108 Steps:  12 Acce: 0.204
# Stage:   5 Beta: 0.507 Steps:  20 Acce: 0.046
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.068
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.743
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.707
# Stage:   3 Beta: 0.013 Steps:   3 Acce: 0.343
# Stage:   4 Beta: 0.014 Steps:  10 Acce: 0.238
# Stage:   5 Beta: 0.161 Steps:  16 Acce: 0.061
# Stage:   6 Beta: 0.908 Steps:  25 Acce: 0.068
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.047
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.765
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.670
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.285
# Stage:   4 Beta: 0.116 Steps:  13 Acce: 0.212
# Stage:   5 Beta: 0.852 Steps:  19 Acce: 0.057
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.038
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.756
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.593
# Stage:   3 Beta: 0.005 Steps:   5 Acce: 0.330
# Stage:   4 Beta: 0.122 Steps:  11 Acce: 0.238
# Stage:   5 Beta: 0.944 Steps:  16 Acce: 0.059
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.042
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.742
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.657
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.330
# Stage:   4 Beta: 0.147 Steps:  11 Acce: 0.250
# Stage:   5 Beta: 0.697 Steps:  16 Acce: 0.058
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.056
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.752
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.633
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.378
# Stage:   4 Beta: 0.037 Steps:   9 Acce: 0.261
# Stage:   5 Beta: 0.467 Steps:  15 Acce: 0.071
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.047
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.748
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.660
# Stage:   3 Beta: 0.008 Steps:   4 Acce: 0.282
# Stage:   4 Beta: 0.080 Steps:  13 Acce: 0.255
# Stage:   5 Beta: 0.395 Steps:  15 Acce: 0.081
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.066
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.770
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.650
# Stage:   3 Beta: 0.011 Steps:   4 Acce: 0.438
# Stage:   4 Beta: 0.038 Steps:   8 Acce: 0.229
# Stage:   5 Beta: 0.215 Steps:  17 Acce: 0.046
# Stage:   6 Beta: 0.745 Steps:  25 Acce: 0.049
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.026
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.787
# Stage:   2 Beta: 0.005 Steps:   2 Acce: 0.720
# Stage:   3 Beta: 0.012 Steps:   3 Acce: 0.330
# Stage:   4 Beta: 0.047 Steps:  11 Acce: 0.249
# Stage:   5 Beta: 0.291 Steps:  16 Acce: 0.052
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.032
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.768
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.567
# Stage:   3 Beta: 0.017 Steps:   5 Acce: 0.376
# Stage:   4 Beta: 0.017 Steps:   9 Acce: 0.246
# Stage:   5 Beta: 0.110 Steps:  16 Acce: 0.073
# Stage:   6 Beta: 0.501 Steps:  25 Acce: 0.029
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.071
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.776
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.547
# Stage:   3 Beta: 0.015 Steps:   5 Acce: 0.318
# Stage:   4 Beta: 0.016 Steps:  12 Acce: 0.182
# Stage:   5 Beta: 0.171 Steps:  22 Acce: 0.080
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.075
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.056
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.747
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.590
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.316
# Stage:   4 Beta: 0.095 Steps:  12 Acce: 0.278
# Stage:   5 Beta: 0.348 Steps:  14 Acce: 0.073
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.072
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.746
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.617
# Stage:   3 Beta: 0.013 Steps:   4 Acce: 0.357
# Stage:   4 Beta: 0.013 Steps:  10 Acce: 0.178
# Stage:   5 Beta: 0.145 Steps:  23 Acce: 0.154
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.052
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.757
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.603
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.312
# Stage:   4 Beta: 0.079 Steps:  12 Acce: 0.261
# Stage:   5 Beta: 0.394 Steps:  15 Acce: 0.074
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.040
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.741
# Stage:   2 Beta: 0.008 Steps:   3 Acce: 0.580
# Stage:   3 Beta: 0.016 Steps:   5 Acce: 0.330
# Stage:   4 Beta: 0.016 Steps:  11 Acce: 0.174
# Stage:   5 Beta: 0.040 Steps:  24 Acce: 0.074
# Stage:   6 Beta: 0.159 Steps:  25 Acce: 0.038
# Stage:   7 Beta: 0.533 Steps:  25 Acce: 0.050
# Stage:   8 Beta: 1.000 Steps:  25 Acce: 0.056
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.750
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.670
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.328
# Stage:   4 Beta: 0.091 Steps:  11 Acce: 0.225
# Stage:   5 Beta: 0.777 Steps:  18 Acce: 0.071
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.086
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.758
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.573
# Stage:   3 Beta: 0.007 Steps:   5 Acce: 0.330
# Stage:   4 Beta: 0.065 Steps:  11 Acce: 0.167
# Stage:   5 Beta: 0.579 Steps:  25 Acce: 0.044
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.064
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.760
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.633
# Stage:   3 Beta: 0.005 Steps:   4 Acce: 0.347
# Stage:   4 Beta: 0.130 Steps:  10 Acce: 0.216
# Stage:   5 Beta: 1.000 Steps:  18 Acce: 0.051
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.748
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.607
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.242
# Stage:   4 Beta: 0.099 Steps:  16 Acce: 0.194
# Stage:   5 Beta: 0.901 Steps:  21 Acce: 0.050
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.079
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.726
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.570
# Stage:   3 Beta: 0.006 Steps:   5 Acce: 0.352
# Stage:   4 Beta: 0.070 Steps:  10 Acce: 0.280
# Stage:   5 Beta: 1.000 Steps:  14 Acce: 0.078
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.734
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.617
# Stage:   3 Beta: 0.006 Steps:   4 Acce: 0.310
# Stage:   4 Beta: 0.138 Steps:  12 Acce: 0.209
# Stage:   5 Beta: 1.000 Steps:  19 Acce: 0.055
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.725
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.593
# Stage:   3 Beta: 0.013 Steps:   5 Acce: 0.404
# Stage:   4 Beta: 0.014 Steps:   8 Acce: 0.198
# Stage:   5 Beta: 0.060 Steps:  20 Acce: 0.097
# Stage:   6 Beta: 0.848 Steps:  25 Acce: 0.050
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.058
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.744
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.603
# Stage:   3 Beta: 0.010 Steps:   4 Acce: 0.360
# Stage:   4 Beta: 0.039 Steps:  10 Acce: 0.255
# Stage:   5 Beta: 0.269 Steps:  15 Acce: 0.049
# Stage:   6 Beta: 0.918 Steps:  25 Acce: 0.085
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.053
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.003 Steps:  25 Acce: 0.754
# Stage:   2 Beta: 0.005 Steps:   3 Acce: 0.597
# Stage:   3 Beta: 0.005 Steps:   5 Acce: 0.324
# Stage:   4 Beta: 0.087 Steps:  11 Acce: 0.178
# Stage:   5 Beta: 0.685 Steps:  23 Acce: 0.040
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.061
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.754
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.527
# Stage:   3 Beta: 0.008 Steps:   6 Acce: 0.313
# Stage:   4 Beta: 0.062 Steps:  12 Acce: 0.270
# Stage:   5 Beta: 0.320 Steps:  14 Acce: 0.094
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.080
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.741
# Stage:   2 Beta: 0.007 Steps:   3 Acce: 0.530
# Stage:   3 Beta: 0.016 Steps:   6 Acce: 0.362
# Stage:   4 Beta: 0.016 Steps:  10 Acce: 0.244
# Stage:   5 Beta: 0.342 Steps:  16 Acce: 0.061
# Stage:   6 Beta: 1.000 Steps:  25 Acce: 0.064
# Sample initial stage: ...
# Stage:   0 Beta: 0.002 Steps:  25 Acce: 1.000
# Stage:   1 Beta: 0.002 Steps:  25 Acce: 0.765
# Stage:   2 Beta: 0.006 Steps:   3 Acce: 0.610
# Stage:   3 Beta: 0.007 Steps:   4 Acce: 0.333
# Stage:   4 Beta: 0.043 Steps:  11 Acce: 0.236
# Stage:   5 Beta: 0.203 Steps:  17 Acce: 0.069
# Stage:   6 Beta: 0.666 Steps:  25 Acce: 0.076
# Stage:   7 Beta: 1.000 Steps:  25 Acce: 0.059

# %% [markdown]
# After the code is finished, save the output into csv files for post-processing.

# %%
np.savetxt('simR0.csv', postSimR0, delimiter=',')
np.savetxt('simM.csv', postSimM, delimiter=',');

# %%
np.savetxt('simR0bb.csv', postSimR0b, delimiter=',')
